# %% [markdown]
# <a href="https://colab.research.google.com/github/Akita20/Practice/blob/master/AlexNet_8_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AlexNet-8 Model

# %% [markdown]
# ## Problem Statement: Binary Sentiment Classification using a CNN
#
# ### Objective
# Develop a Convolutional Neural Network (CNN) model to accurately classify movie reviews from the IMDB dataset as positive or negative.
#
# ### Dataset
# The IMDB dataset consists of 50,000 movie reviews (25,000 for training and 25,000 for testing) labeled as either positive or negative. Reviews have been preprocessed and encoded as a sequence of integers representing the words in the text.
# ![image.png](data:image/png;base64,...)
# ### Model
# A 1D CNN model is used for this task. The model consists of an **embedding layer**, a **convolutional layer** with **ReLU activation**, a global **max pooling** layer, and a dense output layer with a **sigmoid activation function**.
#
# ![image.png](data:image/png;base64,...)
#
# ### Training
# The model is trained using the **Adam optimizer** and **binary cross-entropy** loss function. The training is performed for **10 epochs** with a **batch size of 32**.
#
# ### Evaluation
# The model's performance is evaluated on the test dataset, and the accuracy is reported.
#
# ### Expected Outcome
# A trained 1D CNN model capable of effectively classifying movie reviews from the IMDB dataset as positive or negative with high accuracy.
#
# ### Code Example

# %%
# %%time
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load and preprocess the IMDB dataset
vocab_size = 10000
maxlen = 100

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=vocab_size)

train_data = pad_sequences(train_data, maxlen=maxlen)
test_data = pad_sequences(test_data, maxlen=maxlen)

# Define the 1D CNN model
embedding_dim = 16

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=maxlen),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(train_data, train_labels, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test dataset
test_loss, test_acc = model.evaluate(test_data, test_labels)
print('Test accuracy:', test_acc)
# Out:
# ...
# 17464789/17464789 [==============================] - 0s 0us/step
# Epoch 1/10
# 625/625 [==============================] - 10s 15ms/step - loss: 0.5235 - accuracy: 0.7239 - val_loss: 0.3992 - val_accuracy: 0.8182
# Epoch 2/10
# 625/625 [==============================] - 9s 15ms/step - loss: 0.3202 - accuracy: 0.8655 - val_loss: 0.3548 - val_accuracy: 0.8432
# Epoch 3/10
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2107 - accuracy: 0.9192 - val_loss: 0.3780 - val_accuracy: 0.8410
# Epoch 4/10
# 625/625 [==============================] - 9s 14ms/step - loss: 0.1335 - accuracy: 0.9546 - val_loss: 0.4311 - val_accuracy: 0.8364
# Epoch 5/10
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0766 - accuracy: 0.9781 - val_loss: 0.5098 - val_accuracy: 0.8254
# Epoch 6/10
# 625/625 [==============================] - 8s 13ms/step - loss: 0.0405 - accuracy: 0.9904 - val_loss: 0.5766 - val_accuracy: 0.8292
# Epoch 7/10
# ...
