# %% [markdown]
# <a href="https://colab.research.google.com/github/Akita20/Practice/blob/master/CNN_project_for_MNIST_digit_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CNN project for MNIST digit recognition in Google Colab.
#
# **Project Outline**
#
# **1. Problem Statement**
#
# * **Objective:** Develop a Convolutional Neural Network (CNN) capable of accurately classifying handwritten digits from the MNIST dataset.
#
# **2. Dataset**
#
# * **MNIST Dataset:** A classic computer vision dataset consisting of 70,000 grayscale images of handwritten digits (0-9). Each image is 28x28 pixels in size.
#     * 60,000 training images
#     * 10,000 testing images

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The MNIST database (Modified National Institute of Standards and Technology database) is a large collection of handwritten digits. It has a training set of 60,000 examples, and a test set of 10,000 examples. It is a subset of a larger NIST Special Database 3 (digits written by employees of the United States Census Bureau) and Special Database 1 (digits written by high school students) which contain monochrome images of handwritten digits.

# %% [markdown]
# https://keras.io/api/datasets/mnist/

# %%
# !pip install tensorflow keras

# %% [markdown]
# **4.  Data Loading and Preprocessing**

# %%
import tensorflow as tf
from tensorflow import keras

# Load MNIST dataset
(train_images, train_labels), (test_images, test_labels) = keras.datasets.mnist.load_data()

# Reshape and normalize
train_images = train_images.reshape(60000, 28, 28, 1) / 255.0
test_images = test_images.reshape(10000, 28, 28, 1) / 255.0
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# **5. CNN Model Architecture**

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
    keras.layers.MaxPooling2D(2, 2),
    keras.layers.Conv2D(64, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# **6. Compilation**

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# **7. Training**

# %%
#model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.1306 - accuracy: 0.9600
# Epoch 2/10
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0430 - accuracy: 0.9869
# Epoch 3/10
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0286 - accuracy: 0.9909
# Epoch 4/10
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0216 - accuracy: 0.9930
# Epoch 5/10
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.0155 - accuracy: 0.9951
# Epoch 6/10
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.0128 - accuracy: 0.9959
# Epoch 7/10
# 1875/1875 [==============================] - 51s 27ms/step - loss: 0.0091 - accuracy: 0.9970
# Epoch 8/10
# 1875/1875 [==============================] - 51s 27ms/step - loss: 0.0091 - accuracy: 0.9971
# Epoch 9/10
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.0065 - accuracy: 0.9977
# Epoch 10/10
# ...

# %%
predictions= model.predict(test_images)
# Out:
# 313/313 [==============================] - 3s 8ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# function to plot image and prediction
def plot_image_prediction(index):
  plt.figure(figsize= (6,3))
  plt.imshow(test_images[index].reshape(28,28), cmap='gray')
  pred_class = np.argmax(predictions[index])
  true_class = test_labels[index]
  plt.xlabel("Predicted: {}, True: {}".format(pred_class, true_class))

# %%
# Display a few examples
for i in range(5):
    plot_image_prediction(i)
    plt.show()

# %% [markdown]
# **8. Evaluation**

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('Test accuracy:', test_acc)
# Out:
# 313/313 - 2s - loss: 0.0389 - accuracy: 0.9903 - 2s/epoch - 8ms/step
# Test accuracy: 0.9902999997138977

# %%
function to

# %% [markdown]
# **Explanation**
#
# * **Convolutional Layers (Conv2D):** Extract features from the image input.
# * **Pooling Layers (MaxPooling2D):** Reduce image dimensionality and focus on the most important features.
# * **Flatten:** Prepares the data for the dense layers.
# * **Dense Layers:** Perform the final classification task.
# * **Softmax Activation:** Outputs probabilities for each digit class.
#
# **Additional Notes:**
#
# *  **TensorFlow/Keras:**  Powerful libraries for deep learning.
# * **Experiment:**  Play around with the number of layers, neurons, filter sizes, activation functions, etc., to see how they affect performance.
# * **Data Augmentation:** Can improve generalization by techniques like image rotation, shifting, and adding noise.
#
# **Let me know if you'd like to make modifications, enhancements, or explore more advanced techniques!**

# %% [markdown]
# <div class="md-recitation">
#   Sources
#   <ol>
#   <li><a href="https://github.com/Rettend/Tensorflow">https://github.com/Rettend/Tensorflow</a></li>
#   <li><a href="https://ioecapsule.com/deep-learning-detecting-clothing-items-with-tensorflow-and-keras/">https://ioecapsule.com/deep-learning-detecting-clothing-items-with-tensorflow-and-keras/</a></li>
#   <li><a href="https://github.com/JiA1996/intro-to-TensorFlow">https://github.com/JiA1996/intro-to-TensorFlow</a></li>
#   </ol>
# </div>
